# %%
import matplotlib.pyplot as plt
#population=[22,55,33,4,,4,5,76,7,8,6,33,5,35,54,4,4,4,4,4]
# %matplotlib inline

# %%
x=[2,3,5,5,6]
y=[2,3,7,4,5]
plt.xlabel('x')
plt.ylabel('y')
plt.title('Intersting Graph\nCheck it out')

# %%
plt.scatter(x,y,label='skitscat',color='k',marker='o',s=100)

# %%
plt.show()

# %%
#stack plots

# %%
days=[1,2,3,4,5,6]
sleeping=[7,8,9,6,7,8]
eating=[2,3,4,2,2,2]
working=[7,8,6,5,7,8,]
playing=[4,5,3,2,4,5]

# %%
plt.stackplot(days,sleeping,eating,working,playing)
# Out:
# [<matplotlib.collections.PolyCollection at 0x7ed22b0>,
#  <matplotlib.collections.PolyCollection at 0x7ed2908>,
#  <matplotlib.collections.PolyCollection at 0x7ed2f98>,
#  <matplotlib.collections.PolyCollection at 0x7edb630>]

# %%
plt.show()#cant have labels

# %%
#PIE Chart
slices=[7,2,2,3,12]

# %%
activties=['s','f','d','r','t']

# %%
plt.pie(slices,labels=activties)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f329e8>,
#   <matplotlib.patches.Wedge at 0x7f376a0>,
#   <matplotlib.patches.Wedge at 0x7f3c320>,
#   <matplotlib.patches.Wedge at 0x7f3cf60>,
#   <matplotlib.patches.Wedge at 0x7f43be0>],
#  [<matplotlib.text.Text at 0x7f37240>,
#   <matplotlib.text.Text at 0x7f37e80>,
#   <matplotlib.text.Text at 0x7f3cb00>,
#   <matplotlib.text.Text at 0x7f43780>,
#   <matplotlib.text.Text at 0x7f48400>])

# %%
plt.show()
plt.pie(slices,labels=activties,startangle=90,shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f999b0>,
#   <matplotlib.patches.Wedge at 0x7fa32e8>,
#   <matplotlib.patches.Wedge at 0x7faaba8>,
#   <matplotlib.patches.Wedge at 0x7fb84a8>,
#   <matplotlib.patches.Wedge at 0x7fbcd68>],
#  [<matplotlib.text.Text at 0x7f9f7f0>,
#   <matplotlib.text.Text at 0x7faa0f0>,
#   <matplotlib.text.Text at 0x7fb19b0>,
#   <matplotlib.text.Text at 0x7fbc2b0>,
#   <matplotlib.text.Text at 0x7fc1b70>],
#  [<matplotlib.text.Text at 0x7f9fd68>,
#   <matplotlib.text.Text at 0x7faa668>,
#   <matplotlib.text.Text at 0x7fb1f28>,
#   <matplotlib.text.Text at 0x7fbc828>,
#   <matplotlib.text.Text at 0x7fc8128>])

# %%
plt.show()

# %%
#Load data from files

# %%
import csv

# %%
x=[]
y=[]
with open('sample.txt','r') as csv file:
# Out:
#   File "<ipython-input-32-63ccc0d78826>", line 3
#     with open('sample.txt','r') as csv file:
#                                           ^
# SyntaxError: invalid syntax

# %%
plots=csv.reader(csvfile,delimter=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-00ee7e9f970b> in <module>()
# ----> 1 plots=csv.reader(csvfile,delimter=',')
#
# NameError: name 'csvfile' is not defined

# %%
foe row in plots:
    x.append[int(row[0])]
    y.append[int(row[1])]
# Out:
#   File "<ipython-input-34-75ac31d75fbc>", line 1
#     foe row in plots:
#           ^
# SyntaxError: invalid syntax

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
import numpy as np

# %%
x,y=np.loadtxt(' \Libraries\Documents\sample.txt',delimiter=',',unpack=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-1fcaa49b0b64> in <module>()
# ----> 1 x,y=np.loadtxt(' \Libraries\Documents\sample.txt',delimiter=',',unpack=True)
#
# D:\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(open(fname, 'U'))
#     802             else:
# --> 803                 fh = iter(open(fname))
#     804         else:
#     805             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: ' \\Libraries\\Documents\\sample.txt'

# %%
g=open("\Users\p2admin\Downloads\sample.txt")
# Out:
#   File "<ipython-input-39-1085224f5e3d>", line 1
#     g=open("\Users\p2admin\Downloads\sample.txt")
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape

# %%
#getting data from internet
#import %matplotlib.pyplot as plt
import urllib
importmatplotlib.dates as mdates

def graph_data(stock):
    stock_price_url='http://chartapi.finance.yahoo.com/instrument/1.0/' +stock+ '/chartdata;type=quote;range=10y/csv'
    stock_data=[]
    graph_data('TESLA')
